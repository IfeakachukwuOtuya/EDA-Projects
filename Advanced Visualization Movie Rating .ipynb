# %%
# MOVIE RATING ANALYSIS (ADVANCED VISUALIZATION)

import pandas as pd
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\User\\Ifeakachukwu_IT_Material'

# %%
data = pd.read_csv(r"C:\Users\User\Ifeakachukwu_IT_Material\Movie-Rating.csv")
data
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
len(data)
# Out:
# 559

# %%
data.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
data.tail()
# Out:
#                 Film     Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 554    Your Highness    Comedy                         26                  36
# 555  Youth in Revolt    Comedy                         68                  52
# 556           Zodiac  Thriller                         89                  73
# 557      Zombieland     Action                         90                  87
# 558        Zookeeper    Comedy                         14                  42
#
#      Budget (million $)  Year of release
# 554                  50             2011
# 555                  18             2009
# 556                  65             2007
# 557                  24             2009
# 558                  80             2011

# %%
data.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
data.columns = ['Film', 'Genre', 'CriticRatings', 'AudienceRatings',
       'BudgetMillion', 'Year']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    object
#  1   Genre            559 non-null    object
#  2   CriticRatings    559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   BudgetMillion    559 non-null    int64
#  5   Year             559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
data.describe().T
# Out:
#                  count         mean        std     min     25%     50%  \
# CriticRatings    559.0    47.309481  26.413091     0.0    25.0    46.0
# AudienceRatings  559.0    58.744186  16.826887     0.0    47.0    58.0
# BudgetMillion    559.0    50.236136  48.731817     0.0    20.0    35.0
# Year             559.0  2009.152057   1.362632  2007.0  2008.0  2009.0
#
#                     75%     max
# CriticRatings      70.0    97.0
# AudienceRatings    72.0    96.0
# BudgetMillion      65.0   300.0
# Year             2010.0  2011.0

# %%
# if you look at the year the data type is int but when you look at the mean value its showing 2009 which is meaningless
# we have to change to categorical type
# also from object datatyoe we will convert to category datatypes

# %%
data['Film']
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: object

# %%
data.Film
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: object

# %%
data.Film = data.Film.astype('category')

data.Genre = data.Genre.astype('category')

data.Year = data.Year.astype('category')
data.Year    # is it real no. year you can take average, min, max but out come have no meaning
# Out:
# 0      2009
# 1      2008
# 2      2009
# 3      2010
# 4      2009
#        ...
# 554    2011
# 555    2009
# 556    2007
# 557    2009
# 558    2011
# Name: Year, Length: 559, dtype: category
# Categories (5, int64): [2007, 2008, 2009, 2010, 2011]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    category
#  1   Genre            559 non-null    category
#  2   CriticRatings    559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   BudgetMillion    559 non-null    int64
#  5   Year             559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
data['Genre'].cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
data.Genre.unique()
# Out:
# ['Comedy', 'Adventure', 'Action', 'Horror', 'Drama', 'Romance', 'Thriller']
# Categories (7, object): ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']

# %%
data.describe()
# Out:
#        CriticRatings  AudienceRatings  BudgetMillion
# count     559.000000       559.000000     559.000000
# mean       47.309481        58.744186      50.236136
# std        26.413091        16.826887      48.731817
# min         0.000000         0.000000       0.000000
# 25%        25.000000        47.000000      20.000000
# 50%        46.000000        58.000000      35.000000
# 75%        70.000000        72.000000      65.000000
# max        97.000000        96.000000     300.000000

# %%
# To work with joint plots
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings 
warnings.filterwarnings('ignore')

# %%
# basically joint plots is scatter plot and it find the relation between audience and critics
# also if you at the dist below you can find the uniform distribution (critics rating) and normal distribution (audience)

# %%
data.columns
# Out:
# Index(['Film', 'Genre', 'CriticRatings', 'AudienceRatings', 'BudgetMillion',
#        'Year'],
#       dtype='object')

# %%
sns.histplot(data['CriticRatings'])
plt.show()

# %%
sns.histplot(data['AudienceRatings'])
plt.show()

# %%
j = sns.jointplot(data=data, x='CriticRatings', y='AudienceRatings')
j
plt.show()

# %%
# Audience rating is more dominant than critics rating
# Based on this we find that most people are most likelihood to watch audiemce rating and less likely to watch critics rating
# let me explain the excel -- if you filter  audience reating, and critic rating, critic rating has very low values compared to audence ratings

# %%
j = sns.jointplot(data=data, x='CriticRatings', y='AudienceRatings', kind='hex')
j
plt.show()

# %%
m1 = sns.distplot(data['AudienceRatings'])
m1
plt.show()

# %%
sns.set_style('darkgrid')

# %%
m2 = sns.distplot(data['AudienceRatings'], bins=15)
m2
plt.show()

# %%
sns.set_style('whitegrid')
n1 = sns.distplot(data['AudienceRatings'], bins=15)
n1
plt.show()

# %%
sns.set_style('white')
n1 = sns.distplot(data['AudienceRatings'], bins=20)   # Normal distribution called bell curve
n1
plt.show()

# %%
n1 = sns.histplot(data['CriticRatings'], bins=20)   #Uniform distribution 
n1
plt.show()

# %%
# Creating stacked histogram

# %%
data.columns
# Out:
# Index(['Film', 'Genre', 'CriticRatings', 'AudienceRatings', 'BudgetMillion',
#        'Year'],
#       dtype='object')

# %%
plt.hist(data.BudgetMillion)
plt.show()

# %%
data[data['Genre'] == 'Drama']   # filters out all the Drama
# Out:
#                     Film  Genre  CriticRatings  AudienceRatings  \
# 10            88 Minutes  Drama              5               51
# 11    A Dangerous Method  Drama             79               89
# 13        A Serious Man   Drama             89               64
# 18          Albert Nobbs  Drama             53               43
# 23       All Good Things  Drama             33               64
# ..                   ...    ...            ...              ...
# 529            War Horse  Drama             77               73
# 532  Water For Elephants  Drama             60               72
# 534     We Own the Night  Drama             55               63
# 541             Whip It   Drama             84               73
# 545        Winter's Bone  Drama             94               73
#
#      BudgetMillion  Year
# 10              30  2007
# 11              20  2011
# 13               7  2009
# 18               8  2011
# 23              20  2010
# ..             ...   ...
# ...

# %%
plt.hist(data[data['Genre'] == 'Drama'].BudgetMillion)
plt.show()

# %%
plt.hist(data[data['Genre'] == 'Drama'].CriticRatings)
plt.show()

# %%
data.head()
# Out:
#                     Film      Genre  CriticRatings  AudienceRatings  \
# 0  (500) Days of Summer      Comedy             87               81
# 1            10,000 B.C.  Adventure              9               44
# 2             12 Rounds      Action             30               52
# 3              127 Hours  Adventure             93               84
# 4              17 Again      Comedy             55               70
#
#    BudgetMillion  Year
# 0              8  2009
# 1            105  2008
# 2             20  2009
# 3             18  2010
# 4             20  2009

# %%
# Below plots are stacked histogram becuase overlaped
plt.hist(data[data.Genre == 'Action'].BudgetMillion, bins=20)  
plt.hist(data[data.Genre == 'Thriller'].BudgetMillion, bins=20)  
plt.hist(data[data.Genre == 'Drama'].BudgetMillion, bins=20)  
plt.legend()
plt.show()

# %%
plt.hist([data[data.Genre == 'Action'].BudgetMillion, 
         data[data.Genre == 'Thriller'].BudgetMillion,
         data[data.Genre == 'Drama'].BudgetMillion,
         data[data.Genre == 'Comedy'].BudgetMillion], 
         bins=20, stacked=True) 
plt.legend()
plt.show()

# %%
# if we have 100 categories we cannot copy and paste all
for gen in data.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
data['Genre'].cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
data.head()
# Out:
#                     Film      Genre  CriticRatings  AudienceRatings  \
# 0  (500) Days of Summer      Comedy             87               81
# 1            10,000 B.C.  Adventure              9               44
# 2             12 Rounds      Action             30               52
# 3              127 Hours  Adventure             93               84
# 4              17 Again      Comedy             55               70
#
#    BudgetMillion  Year
# 0              8  2009
# 1            105  2008
# 2             20  2009
# 3             18  2010
# 4             20  2009

# %%
vis1 = sns.lmplot(data=data, x='CriticRatings', y='AudienceRatings',
                 fit_reg=False)
plt.show()

# %%
vis1 = sns.lmplot(data=data, x='CriticRatings', y='AudienceRatings',
                 fit_reg=False, hue='Genre')
plt.show()

# %%
# Kernel Density Estimate plot (KED PLOT)
# How can i visualize audience rating and critics rating using scatterplot

# %%
k1 = sns.kdeplot(data=data, x= 'CriticRatings', y='AudienceRatings')
                 
plt.show()
# where do u find more density and how density is distibuted across from the the chat 
# center point is kernal this is calld KDE & insteade of dots it visualize like this
# we can able to clearly see the spread at the audience ratings

# %%
k1 = sns.kdeplot(data=data, x= 'BudgetMillion', y='AudienceRatings')
                 
plt.show()

# %%
k1 = sns.kdeplot(data=data, x='CriticRatings', y='AudienceRatings', shade=True, shade_lowest=False, cmap='Accent_r')
                 
plt.show()

# %%
sns.set_style('dark')
k1 = sns.kdeplot(data=data, x='BudgetMillion', y='AudienceRatings', shade=True, shade_lowest=False, cmap='plasma_r')
                 
plt.show()

# %%
sns.set_style('darkgrid')
k1 = sns.kdeplot(data=data, x='BudgetMillion', y='AudienceRatings', shade=True, shade_lowest=False, cmap='Greens_r')
                 
plt.show()

# %%
sns.set_style('darkgrid')
k1 = sns.kdeplot(data=data, x='BudgetMillion', y='AudienceRatings')
                 
plt.show()

# %%
sns.set_style('darkgrid')
k1 = sns.kdeplot(data=data, x='BudgetMillion', y='CriticRatings')
                 
plt.show()

# %%
# Subplots
f, ax = plt.subplots(1,2, figsize=(12,6))
plt.show()

# %%
f, axes = plt.subplots(1,2, figsize=(12,6))
k1 = sns.kdeplot(data=data, x='BudgetMillion', y='AudienceRatings', ax=axes[0])
k2 = sns.kdeplot(data=data, x='BudgetMillion', y='CriticRatings', ax=axes[1])                 
plt.show()

# %%
# where do you find more density and how density is distributed across from the chat
# center point kernel this is called KDE and instead of gots it visualize like this
# we can able to clearly see the spread at the audience ratings

# %%
# Box plots

b = sns.boxplot(data=data, x='Genre', y='CriticRatings')
plt.show()

# %%
# Violin plot
v = sns.violinplot(data=data, x='Genre', y='CriticRatings')
plt.show()

# %%
b2 = sns.barplot(data=data[data.Genre == 'Drama'], x='Year', y='CriticRatings')
plt.show()

# %%
v2 = sns.violinplot(data=data[data.Genre == 'Drama'], x='Year', y='CriticRatings')
plt.show()

# %%
f, ax = plt.subplots(3,3, figsize=(12,6))
plt.show()

# %%
plt.scatter(data.CriticRatings, data.AudienceRatings)
plt.show()

# %%
# Creating a Facet grid
g = sns.FacetGrid(data, row='Genre', col='Year', hue='Genre')  # Kind of subplots
plt.show()

# %%
g = sns.FacetGrid(data, row='Genre', col='Year', hue='Genre')
g = g.map(plt.scatter, 'CriticRatings', 'AudienceRatings')   
plt.show()

# %%
# you can populated any type of chat. 

g =sns.FacetGrid (data, row = 'Genre', col = 'Year', hue = 'Genre')
g = g.map(plt.hist, 'BudgetMillion') #scatterplots are mapped in facetgrid
plt.show()

# %%
g = sns.FacetGrid(data, row='Genre', col='Year', hue='Genre')
kws = dict(s=50, linewidth=0.5, edgecolor='black')
g = g.map(plt.scatter, 'CriticRatings', 'AudienceRatings', **kws)  #sctterplots are mapped in facetgrid
plt.show()

# %%
# From the historical data, more audience are likely to watch Action, Comedy, Honor and Drama

# %%
# Python is not vectorize programming language
# Bulding dashboards (dashboard - combination of chat)

# %%
sns.set_style('darkgrid')
f, axes = plt.subplots(2,2, figsize=(15,15))
k1 = sns.kdeplot(data=data, x='BudgetMillion', y='AudienceRatings', ax=axes[0,0])
k2 = sns.kdeplot(data=data, x='BudgetMillion', y='AudienceRatings', ax=axes[0,1])

k1.set(xlim=(-20.160))
k2.set(xlim=(-20.160))

z = sns.violinplot(data=data[data.Genre == 'Drama'], x='Year', y='CriticRatings', ax=axes[1,0])
k4 = sns.kdeplot(data=data, x='BudgetMillion', y='AudienceRatings', shade=True, shade_lowest=False, cmap='Greens_r')
k4b =sns.kdeplot(data=data, x='CriticRatings', y='AudienceRatings', cmap='BrBG', ax=axes[1,1])

plt.tight_layout()
plt.show()

# %%
# How can you style your dashboard using different color map
# Python is not vectorize programming language
# Building dashboards (dashboard - combination of chats)

sns.set_style('dark',{'axes.facecolor':'white'})
f, axes = plt.subplots(2,2, figsize=(15,15))

#plot [0,0]
k1 = sns.kdeplot(data=data, x='BudgetMillion', y='AudienceRatings', shade=True, shade_lowest=False, cmap='YlGnBu_r', ax=axes[0,0])
kb1 = sns.kdeplot(data=data, x='BudgetMillion', y='AudienceRatings', cmap='cool', ax=axes[0,0])

#plt [0,1]

k2 = sns.kdeplot(data=data, x='BudgetMillion', y='CriticRatings', shade=True, shade_lowest=False, cmap='summer', ax=axes[0,1])
k2b = sns.kdeplot(data=data, x='BudgetMillion', y='AudienceRatings', cmap='cividis', ax=axes[0,1])

#plot [1,0]

z = sns.violinplot(data=data[data.Genre == 'Drama'], x='Year', y='CriticRatings', ax=axes[1,0])

#plot [1,1]
k4 = sns.kdeplot(data=data, x='CriticRatings', y='AudienceRatings', shade=True, shade_lowest=False, cmap='Grays', ax=axes[1,1])
k4b = sns.kdeplot(data=data, x='CriticRatings', y='AudienceRatings', cmap='CMRmap_r', ax=axes[1,1])

k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))

plt.show()
